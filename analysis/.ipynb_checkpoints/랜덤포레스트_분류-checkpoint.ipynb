# %% [markdown]
# - p1,p2,p3,p4 데이터
# - happy, disgusted, calm, sad, fear, confused, surprised, angry 수치 데이터가 있고
# - emtion(target 변수)에는 p(positive),z(normal),n(negative) 정보가 있음

# %%
# 내가 열 순서가 다 달라서 지금 따로따로 만들었는데, 
# 데이터를 미리 열 순서를 맞춰야할지 파이썬으로 맞출지 고민

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from statsmodels.formula.api import ols
from statsmodels.api import qqplot, add_constant
import statsmodels.formula.api as smf
from statsmodels.tools.eval_measures import rmse
# % matplotlib inline

# %%
from sklearn.tree import export_graphviz
import graphviz

from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV

# %%
 # 일단 데이터 합치는 거 난제 하고,, 하나 가지고 먼저 해보자

# %%
df_raw = pd.read_csv('C:\\Users\\SEOJIN\\Desktop\\jongp1_2021\\train_machinelearning\\train data\\text\\p1_entire.csv', engine='python')
df_raw.head()
# Out:
#    HAPPY  DISGUSTED  CALM   SAD  FEAR  CONFUSED  SURPRISED  ANGRY emotion
# 0     98          0      0    0     0         0          0      0       p
# 1     99          0      0    0     0         0          0      0       p
# 2     99          0      0    0     0         0          0      0       p
# 3     99          0      0    0     0         0          0      0       p
# 4     99          0      0    0     0         0          0      0       p

# %%
df_1 = pd.read_csv('C:\\Users\\SEOJIN\\Desktop\\jongp1_2021\\train_machinelearning\\train data\\text\\p1_entire.csv', engine='python')
df_2 = pd.read_csv('C:\\Users\\SEOJIN\\Desktop\\jongp1_2021\\train_machinelearning\\train data\\text\\p2_entire.csv', engine='python')
df_3 = pd.read_csv('C:\\Users\\SEOJIN\\Desktop\\jongp1_2021\\train_machinelearning\\train data\\text\\p3_entire.csv', engine='python')
df_4 = pd.read_csv('C:\\Users\\SEOJIN\\Desktop\\jongp1_2021\\train_machinelearning\\train data\\text\\p4_entire.csv', engine='python')

# %%
plt.rc('font',family='NanumGothic')

# %%
# 데이터가 적어서 교차 검증을 해야할 것 같은데,, oob_score, bootstrap이 관련이 있다?

# %%
# p : 2 z : 1 n : 0
for i in range(len(df_raw['emotion'])):
    if df_raw['emotion'][i] == 'p':
        df_raw['emotion'][i] = 2
    elif df_raw['emotion'][i] == 'z':
        df_raw['emotion'][i] = 1
    else:
        df_raw['emotion'][i] = 0
# df_raw['emotion'] = np.where(df_raw['emotion']=='p',2)
# df_raw['emotion'] = np.where(df_raw['emotion']=='z',1)
# df_raw['emotion'] = np.where(df_raw['emotion']=='n',0)
df_raw.head(50)
# Out:
# <ipython-input-49-b2a43bc2c133>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_raw['emotion'][i] = 2
# <ipython-input-49-b2a43bc2c133>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_raw['emotion'][i] = 1
# <ipython-input-49-b2a43bc2c133>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_raw['emotion'][i] = 0
#     HAPPY  DISGUSTED  CALM   SAD  FEAR  CONFUSED  SURPRISED  ANGRY emotion
# ...

# %%
# 일단 , 잘 모르겠지만 ㄱㄱ해보자

# %%
df_raw_y = df_raw['emotion']
df_raw_x = df_raw.drop('emotion', axis=1, inplace=False)

# %%
df_train_x, df_test_x, df_train_y, df_test_y = train_test_split(df_raw_x, df_raw_y, test_size=0.3, random_state=1234)

print('Train Data X size: {}'.format(df_train_x.shape))
print('Train Data Y size: {}'.format(df_train_y.shape))
print('Test Data X size: {}'.format(df_test_x.shape))
print('Test Data Y size: {}'.format(df_test_y.shape))
# Out:
# Train Data X size: (42, 8)
# Train Data Y size: (42,)
# Test Data X size: (19, 8)
# Test Data Y size: (19,)

# %%
# 아마도 default로 했을 때?
rf_uncustomized = RandomForestRegressor(random_state=1234)
rf_uncustomized.fit(df_train_x, df_train_y)

print('Score on training set:{:.3f}'.format(rf_uncustomized.score(df_train_x, df_train_y)))
print('Score on test set:{:.3f}'.format(rf_uncustomized.score(df_test_x, df_test_y)))
# Out:
# Score on training set:0.994
# Score on test set:0.976
